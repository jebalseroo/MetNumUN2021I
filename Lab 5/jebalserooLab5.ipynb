# %% [markdown]
# Amazon

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 4, 4)

        #1,2. Select AMZN minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("AMZN", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of AMZN and print the average fill price
        #4. Debug the AveragePrice of AMZN
        if not self.Portfolio.Invested:
            self.MarketOrder("AMZN", 100)
            self.Debug(str(self.Portfolio["AMZN"].AveragePrice))

# %% [markdown]
# ![Amazon.png](data:image/png;base64,...)

# %% [markdown]
# Netflix

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 4, 4)

        #1,2. Select NFLX minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("NFLX", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of NFLX and print the average fill price
        #4. Debug the AveragePrice of NFLX
        if not self.Portfolio.Invested:
            self.MarketOrder("NFLX", 100)
            self.Debug(str(self.Portfolio["NFLX"].AveragePrice))

# %% [markdown]
# ![Netflix.png](data:image/png;base64,...)

# %% [markdown]
# Disney

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 4, 4)

        #1,2. Select DIS minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("DIS", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of DIS and print the average fill price
        #4. Debug the AveragePrice of DIS
        if not self.Portfolio.Invested:
            self.MarketOrder("DIS", 100)
            self.Debug(str(self.Portfolio["DIS"].AveragePrice))

# %% [markdown]
# ![Disney.png](data:image/png;base64,...)

# %% [markdown]
# Google

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 11, 4)
        self.SetEndDate(2021, 4, 4)

        #1,2. Select GOOG minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("GOOG", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of GOOG and print the average fill price
        #4. Debug the AveragePrice of GOOG
        if not self.Portfolio.Invested:
            self.MarketOrder("GOOG", 100)
            self.Debug(str(self.Portfolio["GOOG"].AveragePrice))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tesla

# %%
class BootCampTask(QCAlgorithm):
    def Initialize(self):
        self.SetStartDate(2018, 4, 10)
        self.SetEndDate(2021, 4, 10)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("TSLA", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("TSLA", 100)
            self.Debug(str(self.Portfolio["TSLA"].AveragePrice))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
